# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv('../Datasets/Indian_Weddings_ (1).csv')

# %%
df
# Out:
#       Unnamed: 0                Wedding/Type                     Place  \
# 0              0           Heritage Weddings                    Jaipur
# 1              1             Palace Weddings                    Shimla
# 2              2             Resort Weddings                    Shimla
# 3              3             Cruise Weddings                   Alibaug
# 4              4  ////Farmhouse Weddings////                    Shimla
# ...          ...                         ...                       ...
# 4495        4495              Hotel Weddings                 Hyderabad
# 4496        4496              Hotel Weddings                  Tirupati
# 4497        4497     ////Temple Weddings////  ////Agatti Island////xc2
# 4498        4498             Resort Weddings                    Shimla
# 4499        4499           Heritage Weddings                  Tirupati
#
#       Cost/of/Type  Clothes/Bride  Clothes/Groom  Photography   Decor  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Wedding/Type', 'Place', 'Cost/of/Type', 'Clothes/Bride',
#        'Clothes/Groom', 'Photography', 'Decor', 'Decor/Category',
#        'Entertainment', 'Entertainment/Category', 'Gifts(per/piece)',
#        'Gifts/Category', 'Invitations/Cards', 'Cards/Category'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Wedding/Type              0
# Place                     0
# Cost/of/Type              0
# Clothes/Bride             0
# Clothes/Groom             0
# Photography               0
# Decor                     0
# Decor/Category            0
# Entertainment             0
# Entertainment/Category    0
# Gifts(per/piece)          0
# Gifts/Category            0
# Invitations/Cards         0
# Cards/Category            0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# Wedding/Type              object
# Place                     object
# Cost/of/Type               int64
# Clothes/Bride              int64
# Clothes/Groom              int64
# Photography                int64
# Decor                      int64
# Decor/Category            object
# Entertainment              int64
# Entertainment/Category    object
# Gifts(per/piece)           int64
# Gifts/Category            object
# Invitations/Cards          int64
# Cards/Category            object
# dtype: object

# %%
df = df.rename(columns={'Wedding/Type':'Wedding_Type','Cost/of/Type':'Cost_of_Type','Clothes/Bride':'Clothes_Bride',
                    'Clothes/Groom':'Clothes_Groom','Decor/Category':'Decor_Category','Entertainment/Category':'Entertainment_Category',
                    'Gifts(per/piece)':'Gifts_perpiece','Gifts/Category':'Gifts_Category','Invitations/Cards':'Invitations_Cards',
                  'Cards/Category':'Cards_Category','Decor':'Decor_Cost'})

# %%
df.Wedding_Type=df.Wedding_Type.replace("[////]","",regex=True).astype("object")
df.Place=df.Place.replace("[////xc2]","",regex=True).astype("object")

# %%
df
# Out:
#       Unnamed: 0        Wedding_Type          Place  Cost_of_Type  \
# 0              0   Heritage Weddings         Jaipur       7437978
# 1              1     Palace Weddings         Shimla       5777920
# 2              2     Resort Weddings         Shimla       3243944
# 3              3     Cruise Weddings        Alibaug       7064790
# 4              4  Farmhouse Weddings         Shimla       2675924
# ...          ...                 ...            ...           ...
# 4495        4495      Hotel Weddings      Hyderabad        351231
# 4496        4496      Hotel Weddings       Tirupati        876370
# 4497        4497     Temple Weddings  Agatti Island         22518
# 4498        4498     Resort Weddings         Shimla       2379743
# 4499        4499   Heritage Weddings       Tirupati       6781437
#
#       Clothes_Bride  Clothes_Groom  Photography  Decor_Cost  \
# 0            660719         457238        33533      533374
# ...

# %%
df.Wedding_Type.unique()
# Out:
# array(['Heritage Weddings', 'Palace Weddings', 'Resort Weddings',
#        'Cruise Weddings', 'Farmhouse Weddings', 'Beach Weddings',
#        'Temple Weddings', 'Hotel Weddings', 'Destination Weddings'],
#       dtype=object)

# %%
df.Place.unique()
# Out:
# array(['Jaipur', 'Shimla', 'Alibaug', 'Neil Island', 'Mussoorie',
#        'Hyderabad', 'Bangaram Island', 'Goa', 'Mumbai', 'Agatti Island',
#        'Nainital', 'Bangalore', 'Varanasi', 'New Delhi', 'Udaipur',
#        'Jaisalmer', 'Lonavala', 'Rishikesh', 'Tirupati', 'Jodhpur'],
#       dtype=object)

# %%
df.Decor_Category.unique()
# Out:
# array(['Luxury Package', 'Floral Decor', 'Venue Decor/519830', 'Mandap'],
#       dtype=object)

# %%
df.Entertainment_Category.unique()
# Out:
# array(['Celebrity Singers/Dancer', 'Professional Singer/Dance',
#        'Live Band', 'DJ/Sangeet'], dtype=object)

# %%
df.Gifts_Category.unique()
# Out:
# array(['High-Quality', 'Premium Perfumes', 'Edible',
#        'Traditional Handicrafts'], dtype=object)

# %%
df.Cards_Category.unique()
# Out:
# array(['Customized Invitations', 'Boxed', 'Traditional Paper',
#        'Scroll Invitations'], dtype=object)

# %%
df.Wedding_Type.value_counts()
# Out:
# Wedding_Type
# Heritage Weddings       500
# Palace Weddings         500
# Resort Weddings         500
# Cruise Weddings         500
# Farmhouse Weddings      500
# Beach Weddings          500
# Temple Weddings         500
# Hotel Weddings          500
# Destination Weddings    500
# Name: count, dtype: int64

# %%
df.Place.value_counts()
# Out:
# Place
# Jaipur             225
# Shimla             225
# Alibaug            225
# Neil Island        225
# Mussoorie          225
# Hyderabad          225
# Bangaram Island    225
# Goa                225
# Mumbai             225
# Agatti Island      225
# Nainital           225
# Bangalore          225
# Varanasi           225
# New Delhi          225
# Udaipur            225
# Jaisalmer          225
# Lonavala           225
# Rishikesh          225
# Tirupati           225
# Jodhpur            225
# Name: count, dtype: int64

# %%
df.Decor_Category.value_counts()
# Out:
# Decor_Category
# Luxury Package        1671
# Floral Decor          1629
# Venue Decor/519830    1133
# Mandap                  67
# Name: count, dtype: int64

# %%
df.Entertainment_Category.value_counts()
# Out:
# Entertainment_Category
# Celebrity Singers/Dancer     2321
# Professional Singer/Dance    1428
# Live Band                     654
# DJ/Sangeet                     97
# Name: count, dtype: int64

# %%
df.Gifts_Category.value_counts()
# Out:
# Gifts_Category
# High-Quality               1997
# Traditional Handicrafts    1015
# Premium Perfumes           1004
# Edible                      484
# Name: count, dtype: int64

# %%
df.Cards_Category.value_counts()
# Out:
# Cards_Category
# Customized Invitations    1915
# Boxed                     1428
# Scroll Invitations         921
# Traditional Paper          236
# Name: count, dtype: int64

# %%
df.Wedding_Type.value_counts()
# Out:
# Wedding_Type
# Heritage Weddings       500
# Palace Weddings         500
# Resort Weddings         500
# Cruise Weddings         500
# Farmhouse Weddings      500
# Beach Weddings          500
# Temple Weddings         500
# Hotel Weddings          500
# Destination Weddings    500
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0  Cost_of_Type  Clothes_Bride  Clothes_Groom    Photography  \
# count  4500.000000  4.500000e+03    4500.000000    4500.000000    4500.000000
# mean   2249.500000  3.912262e+06  258082.149111  192349.117111  161921.164444
# std    1299.182435  2.895702e+06  255273.762542  191384.209107   81144.000934
# min       0.000000  1.515200e+04   15005.000000    5010.000000   20042.000000
# 25%    1124.750000  1.713427e+06   75530.750000   58418.000000   94058.250000
# 50%    2249.500000  3.447512e+06  140873.000000  113357.000000  161848.000000
# 75%    3374.250000  5.850611e+06  448758.250000  293082.750000  231259.000000
# max    4499.000000  1.199208e+07  999492.000000  898366.000000  299991.000000
#
#           Decor_Cost  Entertainment  Gifts_perpiece  Invitations_Cards
# count    4500.000000    4500.000000     4500.000000        4500.000000
# mean   326960.379556  259857.117556     2753.392222         521.595111
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                    Unnamed: 0  Cost_of_Type  Clothes_Bride  Clothes_Groom  \
# Unnamed: 0           1.000000      0.008520       0.000064       0.025888
# Cost_of_Type         0.008520      1.000000       0.658986       0.476417
# Clothes_Bride        0.000064      0.658986       1.000000       0.539630
# Clothes_Groom        0.025888      0.476417       0.539630       1.000000
# Photography         -0.001179     -0.002172      -0.006578      -0.014266
# Decor_Cost          -0.007601      0.025560       0.020660       0.023076
# Entertainment       -0.012343      0.006096       0.000139       0.016382
# Gifts_perpiece      -0.010595      0.004004       0.012027       0.014876
# Invitations_Cards    0.002066      0.005958       0.015010       0.007548
#
#                    Photography  Decor_Cost  Entertainment  Gifts_perpiece  \
# Unnamed: 0           -0.001179   -0.007601      -0.012343       -0.010595
# Cost_of_Type         -0.002172    0.025560       0.006096        0.004004
# ...

# %%
sb.pairplot(df)

# %%
a=df.groupby('Wedding_Type')['Cost_of_Type'].mean()

# %%
b=df.groupby('Place')['Cost_of_Type'].mean()

# %%
c=df.groupby('Wedding_Type')['Decor_Cost'].mean()

# %%
d=df.groupby('Decor_Category')['Decor_Cost'].mean()

# %%
e=df.groupby('Entertainment_Category')['Entertainment'].mean()

# %%
f= df.groupby('Gifts_Category')['Gifts_perpiece'].mean()

# %%
import matplotlib.pyplot as plt

# %%
sb.barplot(a)
plt.xticks(rotation = 50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.barplot(b)
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.barplot(c)
plt.xticks(rotation = 45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.pivot_table(df, index='Place',columns='Wedding_Type', values='Cost_of_Type',aggfunc='mean',margins='True')
# Out:
# Wedding_Type     Beach Weddings  Cruise Weddings  Destination Weddings  \
# Place
# Agatti Island      3.018720e+06     5.599684e+06          4.232670e+06
# Alibaug            3.130439e+06     5.953619e+06          4.314194e+06
# Bangalore          3.137503e+06     5.934097e+06          4.690533e+06
# Bangaram Island    3.489743e+06     6.215923e+06          3.944307e+06
# Goa                3.372831e+06     5.672584e+06          4.411652e+06
# Hyderabad          3.139120e+06     6.148453e+06          4.486889e+06
# Jaipur             3.435354e+06     6.022499e+06          4.465238e+06
# Jaisalmer          3.203456e+06     5.883751e+06          4.516040e+06
# Jodhpur            3.085721e+06     5.412297e+06          4.111385e+06
# Lonavala           3.207692e+06     6.122445e+06          4.696231e+06
# Mumbai             3.179708e+06     6.160724e+06          4.745828e+06
# Mussoorie          3.454462e+06     5.979435e+06          4.737379e+06
# ...

# %%
pd.pivot_table(df, index='Wedding_Type',columns='Decor_Category', values='Decor_Cost',aggfunc='mean',margins='True')
# Out:
# Decor_Category         Floral Decor  Luxury Package        Mandap  \
# Wedding_Type
# Beach Weddings        298666.468421   500116.769663  56033.000000
# Cruise Weddings       304377.240642   498850.365169  56994.000000
# Destination Weddings  297909.338624   494772.576087  55553.700000
# Farmhouse Weddings    306232.218391   497585.041451  54932.142857
# Heritage Weddings     299675.789773   501587.887255  54077.666667
# Hotel Weddings        303936.565217   498630.500000  55184.833333
# Palace Weddings       296340.389535   496876.517766  53482.600000
# Resort Weddings       295525.321429   499619.886486  56616.750000
# Temple Weddings       295854.767196   495173.672840  55355.687500
# All                   299850.867403   498195.349491  55356.044776
#
# Decor_Category        Venue Decor/519830            All
# Wedding_Type
# Beach Weddings             123695.531746  323378.498000
# Cruise Weddings            131126.196970  326387.098000
# ...

# %%
pd.pivot_table(df, index='Wedding_Type',columns='Entertainment_Category', values='Entertainment',aggfunc='mean',margins='True')
# Out:
# Entertainment_Category  Celebrity Singers/Dancer    DJ/Sangeet     Live Band  \
# Wedding_Type
# Beach Weddings                     367672.867384  23924.363636  69101.690141
# Cruise Weddings                    374607.604743  25061.538462  67592.352113
# Destination Weddings               377261.531120  24984.666667  63523.716049
# Farmhouse Weddings                 379312.988506  23685.142857  63875.291139
# Heritage Weddings                  374825.713208  23313.272727  63937.219178
# Hotel Weddings                     372448.767442  25193.666667  65124.031250
# Palace Weddings                    382213.812030  25360.666667  62461.267606
# Resort Weddings                    377206.510917  25717.285714  64729.585366
# Temple Weddings                    375168.609665  25010.181818  66711.451613
# All                                375556.781560  24760.783505  65154.261468
#
# Entertainment_Category  Professional Singer/Dance            All
# Wedding_Type
# ...

# %%
pd.pivot_table(df, index='Wedding_Type',columns='Cards_Category', values='Invitations_Cards',aggfunc='mean',margins='True')
# Out:
# Cards_Category             Boxed  Customized Invitations  Scroll Invitations  \
# Wedding_Type
# Beach Weddings        645.209040              300.078431          893.988889
# Cruise Weddings       642.524691              298.031390          890.545455
# Destination Weddings  651.145570              313.857820          890.679245
# Farmhouse Weddings    657.748344              294.891892          903.388350
# Heritage Weddings     656.917241              299.182648          898.357143
# Hotel Weddings        658.436709              297.210762          895.989796
# Palace Weddings       644.903846              293.690355          899.807018
# Resort Weddings       645.621951              296.897059          894.900990
# Temple Weddings       647.624204              311.915094          902.826531
# All                   649.819328              300.634987          896.793702
#
# Cards_Category        Traditional Paper         All
# Wedding_Type
# ...

# %%
print(df.Wedding_Type.unique())

w=input("enter wedding type name")

ww=df [df.Wedding_Type==w]

print(df.Place.unique())

p=input("enter Place name")

pp=ww[ww.Place==p]

print(df.Decor_Category.unique())

d=input("enter Decor_Category name")

dd=pp[pp.Decor_Category==d]


q=dd.groupby('Entertainment_Category') ['Entertainment'].mean()

sb.barplot(q)

plt.show()
# Out:
# ['Heritage Weddings' 'Palace Weddings' 'Resort Weddings' 'Cruise Weddings'
#  'Farmhouse Weddings' 'Beach Weddings' 'Temple Weddings' 'Hotel Weddings'
#  'Destination Weddings']
# enter wedding type name Temple Weddings
# ['Jaipur' 'Shimla' 'Alibaug' 'Neil Island' 'Mussoorie' 'Hyderabad'
#  'Bangaram Island' 'Goa' 'Mumbai' 'Agatti Island' 'Nainital' 'Bangalore'
#  'Varanasi' 'New Delhi' 'Udaipur' 'Jaisalmer' 'Lonavala' 'Rishikesh'
#  'Tirupati' 'Jodhpur']
# enter Place name Udaipur
# ['Luxury Package' 'Floral Decor' 'Venue Decor/519830' 'Mandap']
# enter Decor_Category name Luxury Package

# %%
sb.countplot(data=df,x='Wedding_Type')
plt.xticks(rotation = 45)
plt.show()

# %%
sb.countplot(data=df,x='Place')
plt.xticks(rotation =90)
plt.show()

# %%
sb.countplot(df.Decor_Category)
# Out:
# <Axes: xlabel='count', ylabel='Decor_Category'>

# %%
sb.barplot(data=df,x='Wedding_Type',y='Cost_of_Type')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.barplot(data=df,x='Cost_of_Type',y='Place')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.barplot(data=df,x='Decor_Cost',y='Decor_Category')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.barplot(data=df,x='Entertainment',y='Entertainment_Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.lineplot(data=df,x='Wedding_Type',y='Cost_of_Type')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby('Wedding_Type')['Cost_of_Type'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Cost_of_Type'>

# %%
df.groupby('Place')['Cost_of_Type'].sum().plot(kind='pie', figsize=(9,10),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Cost_of_Type'>

# %%
sb.histplot(df.Cost_of_Type)
plt.show()

# %%
sb.histplot(df.Decor_Cost)
plt.show()

# %%
sb.histplot(df.Photography)
# Out:
# <Axes: xlabel='Photography', ylabel='Count'>

# %%
sb.histplot(df.Entertainment)
# Out:
# <Axes: xlabel='Entertainment', ylabel='Count'>

# %%
sb.pointplot(data=df,x='Decor_Cost',y='Wedding_Type')
# Out:
# <Axes: xlabel='Decor_Cost', ylabel='Wedding_Type'>

# %%
sb.pointplot(data=df,x='Cost_of_Type',y='Place')
# Out:
# <Axes: xlabel='Cost_of_Type', ylabel='Place'>

# %%
sb.stripplot(data=df,x='Decor_Category',y='Decor_Cost')
# Out:
# <Axes: xlabel='Decor_Category', ylabel='Decor_Cost'>

# %%
sb.stripplot(data=df,x='Entertainment_Category',y='Entertainment')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.violinplot(y=df['Decor_Cost'])
# Out:
# <Axes: ylabel='Decor_Cost'>

# %%
sb.violinplot(y=df['Entertainment'])
# Out:
# <Axes: ylabel='Entertainment'>

# %%
sb.swarmplot(y=df['Photography'],size=3)
plt.show()

# %%
sb.swarmplot(y=df['Cost_of_Type'],size=1)
plt.show()

# %%
sb.scatterplot(x='Photography', y='Cost_of_Type', data=df) 
plt.show()

# %%
sb.scatterplot(x='Entertainment', y='Cost_of_Type',data=df)
plt.show()

# %%
sb.pairplot(df[['Cost_of_Type','Decor_Cost','Entertainment','Photography','Clothes_Bride','Clothes_Groom']])

# %%
sb.jointplot(x='Photography',y='Cost_of_Type',data=df)

# %%
sb.jointplot(x='Decor_Cost', y='Cost_of_Type',data=df)

# %%
sb.kdeplot(df['Cost_of_Type'], fill=True); plt.show()

# %%
sb.kdeplot(df ['Photography'], fill=True); plt.show()

# %%
sb.countplot(df.Entertainment_Category)
# Out:
# <Axes: xlabel='count', ylabel='Entertainment_Category'>
